# %%
# !pip install ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipynb
#   Downloading ipynb-0.5.1-py3-none-any.whl.metadata (303 bytes)
# Downloading ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# Installing collected packages: ipynb
# Successfully installed ipynb-0.5.1
# WARNING: Ignoring invalid distribution ~illow (C:\Users\admin\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\admin\AppData\Roaming\Python\Python311\site-packages)
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~illow (C:\Users\admin\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\admin\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\admin\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\admin\AppData\Roaming\Python\Python311\site-packages)

# %%
#from ipynb.fs.full.utils1 import get_vec
import numpy as np 
import pandas as pd 
import nltk
import matplotlib.pyplot as plt
from utils import get_vec

# %%
data=pd.read_csv('capitals.txt',delimiter=' ')
data.columns=['city1','country1','city2','country2']
data.head(5)
# Out:
#     city1 country1    city2     country2
# 0  Athens   Greece  Bangkok     Thailand
# 1  Athens   Greece  Beijing        China
# 2  Athens   Greece   Berlin      Germany
# 3  Athens   Greece     Bern  Switzerland
# 4  Athens   Greece    Cairo        Egypt

# %%
import nltk
from gensim.models import KeyedVectors

# %%
word_embeddings=pickle.load(open("word_embedding_subset.p","rb"))
len(word_embedding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 word_embeddings=pickle.load(open("word_embedding_subset.p","rb"))
#       2 len(word_embedding)
#
# NameError: name 'pickle' is not defined
