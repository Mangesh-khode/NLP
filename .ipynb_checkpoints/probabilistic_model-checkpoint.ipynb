# %%
import re
# from collecttions import counter
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import re
# ----> 2 from collecttions import counter
#
# ModuleNotFoundError: No module named 'collecttions'

# %%
text= "red pink pink blue blue yellow ORANGE BLUE BLUE PINK"
text
len(text)
# Out:
# 52

# %%
text_lowercase=text.lower()
text_lowercase
len(text_lowercase)
# Out:
# 52

# %%
word = re.findall(r'\w+',text_lowercase)
word
len(word)
# Out:
# 10

# %%
vocab=set(word)
vocab
len(vocab)
# Out:
# 5

# %%
count_a=dict()
for w in word:
    count_a[w]=count_a.get(w,0)+1
print(count_a)
len(count_a)
# Out:
# {'red': 1, 'pink': 3, 'blue': 4, 'yellow': 1, 'orange': 1}
# 5

# %%
# count_b=dict()
# count_b=Counter(word)
# print(count_b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 count_b=dict()
# ----> 2 count_b=Counter(word)
#       3 print(count_b)
#
# NameError: name 'Counter' is not defined

# %%
d=['blue':count_a['blue'],'pink': count_b['pink'],'red':count_b['red'],'yellow':count_b['yellow'],'orange':count_b['orange']]
# Out:
#   Cell In[22], line 1
#     d=['blue':count_a['blue'],'pink': count_b['pink'],'red':count_b['red'],'yellow':count_b['yellow'],'orange':count_b['orange']]
#              ^
# SyntaxError: invalid syntax

# %%
plt.bar(range(len(d)),list(d.value()),align='center',color=d.keys())
    =plt.tricks(range(len(d)),len(d.keys))
# Out:
#   Cell In[23], line 2
#     =plt.tricks(range(len(d)),len(d.keys))
#     ^
# IndentationError: unexpected indent
