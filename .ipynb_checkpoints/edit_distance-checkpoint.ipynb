# %%
word='dears'

# %%
splits_a=[]
for i in range(len(word)+1):
    splits_a.append([word[:i],word[i:]])
    
for i in splits_a:
    print(i)
# Out:
# ['d', 'dears']
# ['d', 'ears']
# ['d', 'ars']
# ['d', 'rs']
# ['d', 's']
# ['d', '']

# %%
splits_b=[(word[:i],word[i:])for i in range(len(word)+1)]
for i in splits_b:
    print(i)
# Out:
# ('', 'dears')
# ('d', 'ears')
# ('de', 'ars')
# ('dea', 'rs')
# ('dear', 's')
# ('dears', '')

# %%
splits=splits_a
delete=[]
print(word)
for L , R in splits:
    if R:
        print(L+R[1:],'<----DELETE',R[0:])
# Out:
# dears
# dears <----DELETE dears
# dars <----DELETE ears
# drs <----DELETE ars
# ds <----DELETE rs
# d <----DELETE s

# %%
print(word)
one_split=splits[0]
print(one_split)
L=one_split[0]
R=one_split[1]
print(L)
print(R)
print('implecite delete by excluding the leader letter')
print(L+R[1:],R[0])
# Out:
# dears
# ['d', 'dears']
# d
# dears
# implecite delete by excluding the leader letter
# dears d
